# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
import seaborn as sns
import collections

# %%
url = 'imdb_com_movie_data.csv'
df = pd.read_csv(url)
df.head()
# Out:
#                             Uniq Id            Crawl Timestamp  \
# 0  bdce103d6c8ee8206477f5ef43cdd6cf  2019-05-29 12:32:00 +0000
# 1  90bd11174adf73475d088f93a2da28da  2019-05-29 12:30:33 +0000
# 2  df6fc7d029a7e5c214509cbfb513d283  2019-05-29 12:31:05 +0000
# 3  4f73f64a1b559ac76448fd9347bca974  2019-05-29 12:31:37 +0000
# 4  35ced81a516bc02c3f303015cb7a068f  2019-05-29 12:30:49 +0000
#
#                                  Pageurl  \
# 0  https://www.imdb.com/title/tt6791350/
# 1  https://www.imdb.com/title/tt1228705/
# 2  https://www.imdb.com/title/tt2015381/
# 3  https://www.imdb.com/title/tt1825683/
# 4  https://www.imdb.com/title/tt1300854/
#
#                                           Title  \
# 0  Guardians of the Galaxy Vol. 3 (2021) - IMDb
# 1                      Iron Man 2 (2010) - IMDb
# 2         Guardians of the Galaxy (2014) - IMDb
# 3                   Black Panther (2018) - IMDb
# 4                      Iron Man 3 (2013) - IMDb
#
#                            Genres             Release Date Movie Rating  \
# 0                             NaN                      NaN          NaN
# 1         Action|Adventure|Sci-Fi        7 May 2010 (USA)         PG-13
# 2  Action|Adventure|Comedy|Sci-Fi     1 August 2014 (USA)         PG-13
# 3         Action|Adventure|Sci-Fi  16 February 2018 (USA)         PG-13
# 4         Action|Adventure|Sci-Fi        3 May 2013 (USA)         PG-13
#
#    Review Rating Movie Run Time  \
# 0            NaN            NaN
# 1            7.0        124 min
# 2            8.1        121 min
# 3            7.3        134 min
# 4            7.2        130 min
#
#                                                 Plot  \
# 0  Directed by James Gunn. With Elizabeth Debicki...
# 1  Directed by Jon Favreau. With Robert Downey Jr...
# 2  Directed by James Gunn. With Chris Pratt, Vin ...
# 3  Directed by Ryan Coogler. With Chadwick Bosema...
# 4  Directed by Shane Black. With Robert Downey Jr...
#
#                                                 Cast  \
# 0                                                NaN
# 1  Robert Downey Jr.|Mickey Rourke|Gwyneth Paltro...
# 2  Chris Pratt|Vin Diesel|Bradley Cooper|Zoe Saldana
# 3  Chadwick Boseman|Michael B. Jordan|Lupita Nyon...
# 4  Robert Downey Jr.|Guy Pearce|Gwyneth Paltrow|D...
#
#                             Language  \
# 0                            English
# 1             English|French|Russian
# 2                            English
# 3  English|Swahili|Nama|Xhosa|Korean
# 4                            English
#
#                                    Filming Locations           Budget  \
# 0                                                NaN              NaN
# 1  D.C. Stages, 1360 East 6th Street, Downtown, L...   $200,000,000
# 2  Shepperton Studios, Shepperton, Surrey, Englan...   $170,000,000
# 3  Pinewood Atlanta Studios, 461 Sandy Creek Road...   $200,000,000
# 4                          Cary, North Carolina, USA   $200,000,000
#
#        Collection Collection Date
# 0             NaN             NaN
# 1   $623,933,331,  19 August 2010
# 2    $774,176,600             NaN
# 3  $1,347,071,259             NaN
# 4  $1,215,439,994             NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Uniq Id            24 non-null     object
#  1   Crawl Timestamp    24 non-null     object
#  2   Pageurl            24 non-null     object
#  3   Title              24 non-null     object
#  4   Genres             22 non-null     object
#  5   Release Date       23 non-null     object
#  6   Movie Rating       22 non-null     object
#  7   Review Rating      22 non-null     float64
#  8   Movie Run Time     22 non-null     object
#  9   Plot               24 non-null     object
#  10  Cast               22 non-null     object
#  11  Language           24 non-null     object
#  12  Filming Locations  23 non-null     object
#  13  Budget             21 non-null     object
#  14  Collection         22 non-null     object
#  15  Collection Date    4 non-null      object
# dtypes: float64(1), object(15)
# memory usage: 3.1+ KB

# %%
# split the cast string to tuple of all actors
def split_actors(inp):
    input_string = str(inp)
    actor_list = input_string.split("|")
    actor_tuple = tuple(actor_list)
    return actor_tuple

# make a set of all the different actors using for loop
all_actors = ()
for cast in df.Cast:
    cast_actors_tuple = split_actors(cast)
    all_actors += cast_actors_tuple

# make a list with all the casts stitched together
all_moviecasts_list = list(filter(lambda a: a != "nan", all_actors))
print(all_moviecasts_list)
print("="*288)
# make a set with all the different actors
all_actors_set = set(all_actors)
all_actors_set.remove("nan")
print(all_actors_set)
print("="*288)

# check how many times each actor plays in a movie
occurrences_actors = collections.Counter(all_moviecasts_list)
print(occurrences_actors)
# Out:
# ['Robert Downey Jr.', 'Mickey Rourke', 'Gwyneth Paltrow', 'Don Cheadle', 'Chris Pratt', 'Vin Diesel', 'Bradley Cooper', 'Zoe Saldana', 'Chadwick Boseman', 'Michael B. Jordan', "Lupita Nyong'o", 'Danai Gurira', 'Robert Downey Jr.', 'Guy Pearce', 'Gwyneth Paltrow', 'Don Cheadle', 'Edward Norton', 'Liv Tyler', 'Tim Roth', 'William Hurt', 'Brie Larson', 'Samuel L. Jackson', 'Ben Mendelsohn', 'Jude Law', 'Robert Downey Jr.', 'Gwyneth Paltrow', 'Terrence Howard', 'Jeff Bridges', 'Chris Hemsworth', 'Anthony Hopkins', 'Natalie Portman', 'Tom Hiddleston', 'Chris Evans', 'Robert Downey Jr.', 'Scarlett Johansson', 'Sebastian Stan', 'Robert Downey Jr.', 'Chris Hemsworth', 'Mark Ruffalo', 'Chris Evans', 'Tom Holland', 'Michael Keaton', 'Robert Downey Jr.', 'Marisa Tomei', 'Chris Evans', 'Hugo Weaving', 'Samuel L. Jackson', 'Hayley Atwell', 'Robert Downey Jr.', 'Chris Evans', 'Mark Ruffalo', 'Chris Hemsworth', 'Paul Rudd', 'Evangeline Lilly', 'Michael Peña', 'Walton Goggins', 'Paul Rudd', 'Michael Douglas', 'Corey Stoll', 'Evangeline Lilly', 'Chris Hemsworth', 'Natalie Portman', 'Tom Hiddleston', 'Stellan Skarsgård', 'Chris Evans', 'Samuel L. Jackson', 'Scarlett Johansson', 'Robert Redford', 'Robert Downey Jr.', 'Chris Evans', 'Mark Ruffalo', 'Chris Hemsworth', 'Chris Pratt', 'Zoe Saldana', 'Dave Bautista', 'Vin Diesel', 'Chris Hemsworth', 'Tom Hiddleston', 'Cate Blanchett', 'Mark Ruffalo', 'Benedict Cumberbatch', 'Chiwetel Ejiofor', 'Rachel McAdams', 'Benedict Wong', 'Robert Downey Jr.', 'Chris Evans', 'Scarlett Johansson', 'Jeremy Renner']
# ================================================================================================================================================================================================================================================================================================
# {'Tom Holland', 'Chris Hemsworth', 'Sebastian Stan', 'Michael B. Jordan', 'Chiwetel Ejiofor', 'Scarlett Johansson', 'Evangeline Lilly', 'Tim Roth', 'Zoe Saldana', "Lupita Nyong'o", 'Guy Pearce', 'Samuel L. Jackson', 'Terrence Howard', 'Brie Larson', 'Natalie Portman', 'Rachel McAdams', 'Benedict Wong', 'Jeff Bridges', 'Hugo Weaving', 'Michael Douglas', 'Ben Mendelsohn', 'Michael Keaton', 'Benedict Cumberbatch', 'Chris Pratt', 'Walton Goggins', 'Jeremy Renner', 'Tom Hiddleston', 'Vin Diesel', 'Robert Redford', 'Chadwick Boseman', 'Marisa Tomei', 'Chris Evans', 'Anthony Hopkins', 'Stellan Skarsgård', 'Cate Blanchett', 'Mickey Rourke', 'Danai Gurira', 'Hayley Atwell', 'Corey Stoll', 'Robert Downey Jr.', 'Michael Peña', 'Liv Tyler', 'Dave Bautista', 'Mark Ruffalo', 'Jude Law', 'William Hurt', 'Edward Norton', 'Bradley Cooper', 'Don Cheadle', 'Paul Rudd', 'Gwyneth Paltrow'}
# ================================================================================================================================================================================================================================================================================================
# Counter({'Robert Downey Jr.': 9, 'Chris Evans': 7, 'Chris Hemsworth': 6, 'Mark Ruffalo': 4, 'Gwyneth Paltrow': 3, 'Samuel L. Jackson': 3, 'Tom Hiddleston': 3, 'Scarlett Johansson': 3, 'Don Cheadle': 2, 'Chris Pratt': 2, 'Vin Diesel': 2, 'Zoe Saldana': 2, 'Natalie Portman': 2, 'Paul Rudd': 2, 'Evangeline Lilly': 2, 'Mickey Rourke': 1, 'Bradley Cooper': 1, 'Chadwick Boseman': 1, 'Michael B. Jordan': 1, "Lupita Nyong'o": 1, 'Danai Gurira': 1, 'Guy Pearce': 1, 'Edward Norton': 1, 'Liv Tyler': 1, 'Tim Roth': 1, 'William Hurt': 1, 'Brie Larson': 1, 'Ben Mendelsohn': 1, 'Jude Law': 1, 'Terrence Howard': 1, 'Jeff Bridges': 1, 'Anthony Hopkins': 1, 'Sebastian Stan': 1, 'Tom Holland': 1, 'Michael Keaton': 1, 'Marisa Tomei': 1, 'Hugo Weaving': 1, 'Hayley Atwell': 1, 'Michael Peña': 1, 'Walton Goggins': 1, 'Michael Douglas': 1, 'Corey Stoll': 1, 'Stellan Skarsgård': 1, 'Robert Redford': 1, 'Dave Bautista': 1, 'Cate Blanchett': 1, 'Benedict Cumberbatch': 1, 'Chiwetel Ejiofor': 1, 'Rachel McAdams': 1, 'Benedict Wong': 1, 'Jeremy Renner': 1})

# %%
# movies played in bar chart

# convert dictionary to dataframe
movies_per_actor = (pd.DataFrame(list(occurrences_actors.items()),columns = ['Actor','Number_of_movies'])).sort_values(by='Number_of_movies', ascending=False)
movies_per_actor.reset_index(inplace=True, drop=True)

# plot bar chart
fig, ax =plt.subplots(figsize=(10,5))
sns.set_style("darkgrid")
sns.distplot(a=movies_per_actor.Number_of_movies)
ax.set_xticks([x for x in range(10)])
# Out:
# [<matplotlib.axis.XTick at 0x29d49001730>,
#  <matplotlib.axis.XTick at 0x29d49001790>,
#  <matplotlib.axis.XTick at 0x29d492cbac0>,
#  <matplotlib.axis.XTick at 0x29d48fb7520>,
#  <matplotlib.axis.XTick at 0x29d48fb75e0>,
#  <matplotlib.axis.XTick at 0x29d4835fd00>,
#  <matplotlib.axis.XTick at 0x29d4835fb20>,
#  <matplotlib.axis.XTick at 0x29d48fb7130>,
#  <matplotlib.axis.XTick at 0x29d4835f1c0>,
#  <matplotlib.axis.XTick at 0x29d485d94c0>]

# %%
# horizontal bar chart
fig, ax = plt.subplots(figsize=(20,15))
sns.barplot(x="Number_of_movies", y="Actor", data=movies_per_actor)
ax.set_xticks([x for x in range(10)])
# Out:
# [<matplotlib.axis.XTick at 0x29d49072af0>,
#  <matplotlib.axis.XTick at 0x29d49072b20>,
#  <matplotlib.axis.XTick at 0x29d4b17f5e0>,
#  <matplotlib.axis.XTick at 0x29d49063a30>,
#  <matplotlib.axis.XTick at 0x29d49774c70>,
#  <matplotlib.axis.XTick at 0x29d4908b1c0>,
#  <matplotlib.axis.XTick at 0x29d4908b6d0>,
#  <matplotlib.axis.XTick at 0x29d4908bbe0>,
#  <matplotlib.axis.XTick at 0x29d48f22940>,
#  <matplotlib.axis.XTick at 0x29d48f22070>]
